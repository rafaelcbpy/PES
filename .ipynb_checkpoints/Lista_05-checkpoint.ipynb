# %% [markdown]
# #### (5)

# %%
# %matplotlib notebook

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import scipy
import numpy as np
import pandas as pd
import statistics
import math

# %% [markdown]
# ### <center>RECEBIDO<center>

# %%
filename = 'Recebido.mat'
# carregando o arquivo matlab
y = loadmat(filename)

# %%
plt.figure(1)
plt.plot(y['Y'], '--')
plt.ylabel('Y')
plt.legend()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
lista = []
lista1 = []
for i in y['Y']:
    a = i 
    lista.append(i)

listay = []
lista10 = lista
x = 0
p = 200
while(x < p):
    listay.append(lista10[x])
    x+=1
    
x1 = np.arange(0, p, 1)

plt.figure(5)
plt.plot(x1, listay, color='black')
plt.grid()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ### <center>TRANSMITIDO</center>

# %%
filename = 'Transmitido.mat'
# carregando o arquivo matlab
x = loadmat(filename)

# %%
plt.figure(2)
plt.plot(x['X'])
plt.ylabel('X')
plt.legend()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
lista = []
lista1 = []
for i in x['X']:
    a = i 
    lista.append(i)
    
#print(lista)
lista2 = []
lista1 = lista
x = 0
p = 200
while(x < p):
    lista2.append(lista1[x])
    x+=1
x1 = np.arange(0, p, 1)

plt.figure(3)
plt.plot(x1, lista2, color='black')
plt.grid()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
x1 = np.arange(0, p, 1)

plt.figure(4)
plt.plot(x1, listay, color='green', label='Recebido')
plt.plot(x1, lista2, color='black', label='Transmitido')
plt.grid()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = x['X']
Z = np.zeros(len(x1))
  
for i in len(x1):
    if Y(i) >= 0:
        Z(i) = 1
    else:
        Z(i) = -1
# Out:
#   File "<ipython-input-22-4f6f33efdc3c>", line 6
#     Z(i) = 1
#     ^
# SyntaxError: can't assign to function call

# %%
x2 = x['X']
Z = np.zeros(len(x2), 1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-494a0dc7a41c> in <module>
# ----> 1 x2 = x['X']
#       2 Z = np.zeros(len(x2), 1)
#
# TypeError: 'int' object is not subscriptable

# %%
len(x1)
# Out:
# 60
