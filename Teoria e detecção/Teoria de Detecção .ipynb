# %% [markdown]
# ### Um sistema de comunicação binário transmite sinais com valores −1 e +1 sob as hipóteses H0 e H1, respectivamente. O sinal recebido e corrompido por um ruído gaussiano de média nula e variância unitária. Calcule a regra de decisão ótima para obter a taxa de probabilidade mínima. Sendo o dado recebido dado no arquivo Recebido.mat e o sinal transmitido, disponível em Transmitido.mat, calcule a probabilidade de erro nas amostras dadas. OBS: Usar o comando load no MatLab ou Octave para ler os dados.

# %%
# %matplotlib notebook

# %%
from scipy.io import loadmat
import matplotlib.pyplot as plt
import scipy
import numpy as np
import pandas as pd
import statistics
import math

# %% [markdown]
# ### <center>RECEBIDO<center>

# %%
filename = 'Recebido.mat'
# carregando o arquivo matlab
y = loadmat(filename)

# %%
print(y)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Jun 27 15:38:03 2017', '__version__': '1.0', '__globals__': [], 'Y': array([[-0.91838188],
#        [ 0.86893218],
#        [-1.76863167],
#        ...,
#        [ 2.13480434],
#        [ 1.44100939],
#        [ 1.64266642]])}

# %%
y.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Y'])

# %%
print(y['Y'].shape)
# Out:
# (10000, 1)

# %%
plt.figure(1)
plt.plot(y['Y'], '--')
plt.ylabel('Y')
plt.legend()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
lista = []
lista1 = []
for i in y['Y']:
    a = i 
    lista.append(i)

# %%
listay = []
lista10 = lista
x = 0
p = 50
while(x < p):
    listay.append(lista10[x])
    x+=1

# %%
x1 = np.arange(0, p, 1)

plt.figure(5)
plt.plot(x1, listay, color='black')
plt.grid()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %% [markdown]
# ### <center>TRANSMITIDO</center>

# %%
filename = 'Transmitido.mat'
# carregando o arquivo matlab
x = loadmat(filename)

# %%
print(x)
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Tue Jun 27 15:37:54 2017', '__version__': '1.0', '__globals__': [], 'X': array([[ 1],
#        [ 1],
#        [-1],
#        ...,
#        [ 1],
#        [ 1],
#        [ 1]], dtype=int16)}

# %%
x.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'X'])

# %%
print(x['X'].shape)
# Out:
# (10000, 1)

# %%
plt.figure(2)
plt.plot(x['X'], '--')
plt.ylabel('X')
plt.legend()
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
lista = []
lista1 = []
for i in x['X']:
    a = i 
    lista.append(i)
print(lista)
# Out:
# [array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([-1], dtype=int16), array([-1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([1], dtype=int16), array([-1], dtype=int16), array([1], dtype=int16), array([
# ...

# %%
lista2 = []
lista1 = lista
x = 0
p = 40
while(x < p):
    lista2.append(lista1[x])
    x+=1

# %%
x1 = np.arange(0, p, 1)

plt.figure(3)
plt.plot(x1, lista2, color='black')
plt.grid()
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
